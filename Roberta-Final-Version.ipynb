# %% [markdown]
# # Evaluating

# %%
# !pip install -q transformers
# !pip install -q sentencepiece

# %%
from tqdm import tqdm
from IPython.display import clear_output
import torch
from transformers import AutoModelForQuestionAnswering, AutoTokenizer

# %%
path = 'pedramyazdipoor/persian_xlm_roberta_large'
tokenizer = AutoTokenizer.from_pretrained(path)
model = AutoModelForQuestionAnswering.from_pretrained(path)

# %%
class AnswerPredictor:
  def __init__(self, model, tokenizer, device='cuda', n_best=10, max_length=512, stride=256, no_answer=False):
      """Initializes PyTorch Question Answering Prediction
      It's best to leave use the default values.
      Args:
          model: Fine-tuned torch model
          tokenizer: Transformers tokenizer
          device (torch.device): Running device
          n_best (int): Number of best possible answers
          max_length (int): Tokenizer max length
          stride (int): Tokenizer stride
          no_answer (bool): If True, model can return "no answer"
      """
      self.model = model.eval().to(device)
      self.tokenizer = tokenizer
      self.device = device
      self.max_length = max_length
      self.stride = stride
      self.no_answer = no_answer
      self.n_best = n_best


  def model_pred(self, questions, contexts, batch_size=1):
      n = len(contexts)
      if n%batch_size!=0:
          raise Exception("batch_size must be divisible by sample length")

      tokens = self.tokenizer(questions, contexts, add_special_tokens=True,
                              return_token_type_ids=True, return_tensors="pt", padding=True,
                              return_offsets_mapping=True, truncation="only_second",
                              max_length=self.max_length, stride=self.stride)

      start_logits, end_logits = [], []
      for i in tqdm(range(0, n-batch_size+1, batch_size)):
          with torch.no_grad():
              out = self.model(tokens['input_ids'][i:i+batch_size].to(self.device),
                          tokens['attention_mask'][i:i+batch_size].to(self.device),
                          tokens['token_type_ids'][i:i+batch_size].to(self.device))

              start_logits.append(out.start_logits)
              end_logits.append(out.end_logits)

      return tokens, torch.stack(start_logits).view(n, -1), torch.stack(end_logits).view(n, -1)


  def __call__(self, questions, contexts, batch_size=1, answer_max_len=100):
      """Creates model prediction

      Args:
          questions (list): Question strings
          contexts (list): Contexts strings
          batch_size (int): Batch size
          answer_max_len (int): Sets the longests possible length for any answer

      Returns:
          dict: The best prediction of the model
              (e.g {0: {"text": str, "score": int}})
      """
      tokens, starts, ends = self.model_pred(questions, contexts, batch_size=batch_size)
      start_indexes = starts.argsort(dim=-1, descending=True)[:, :self.n_best]
      end_indexes = ends.argsort(dim=-1, descending=True)[:, :self.n_best]

      preds = {}
      for i, (c, q) in enumerate(zip(contexts, questions)):
          min_null_score = starts[i][0] + ends[i][0] # 0 is CLS Token
          start_context = tokens['input_ids'][i].tolist().index(self.tokenizer.sep_token_id)

          offset = tokens['offset_mapping'][i]
          valid_answers = []
          for start_index in start_indexes[i]:
              # Don't consider answers that are in questions
              if start_index<start_context:
                  continue
              for end_index in end_indexes[i]:
                  # Don't consider out-of-scope answers, either because the indices are out of bounds or correspond
                  # to part of the input_ids that are not in the context.
                  if (start_index >= len(offset) or end_index >= len(offset)
                      or offset[start_index] is None or offset[end_index] is None):
                      continue
                  # Don't consider answers with a length that is either < 0 or > max_answer_length.
                  if end_index < start_index or (end_index-start_index+1) > answer_max_len:
                      continue

                  start_char = offset[start_index][0]
                  end_char = offset[end_index][1]
                  valid_answers.append({"score": (starts[i][start_index] + ends[i][end_index]).item(),
                                        "text": c[start_char: end_char]})

          if len(valid_answers) > 0:
              best_answer = sorted(valid_answers, key=lambda x: x["score"], reverse=True)[0]
          else:
              best_answer = {"text": "", "score": min_null_score}

          if self.no_answer:
              preds[i] = best_answer if best_answer["score"] >= min_null_score else {"text": "", "score": min_null_score}
          else:
              preds[i] = best_answer

      return preds

# %%
#@title Paste your Context and ask a Question
context = "باشگاه فوتبال رئال مادرید یک باشگاه حرفه‌ای فوتبال است که در مادرید، پایتخت اسپانیا قرار دارد. رئال موفق‌ترین تیم تاریخ فوتبال اسپانیا و موفق‌ترین تیم تاریخ فوتبال اروپا و موفق‌ترین تیم فوتبال سدهٔ ۲۰ میلادی به انتخاب فیفا است. آن‌ها دارای رکورد ۳۴ بار قهرمانی در لالیگا، ۱۹ قهرمانی در کوپا دل ری (جام حذفی)، ۱۰ سوپرکاپ اسپانیا، ۱۳ قهرمانی در لیگ قهرمانان اروپا، ۲ جام یوفا، ۴ سوپرکاپ اروپا و ۴ قهرمانی در جام باشگاه‌های جهان هستند. رئال مادرید رکورددار قهرمانی در لیگ قهرمانان اروپا با ۱۳ قهرمانی و جام باشگاه های جهان با ۴ قهرمانی است. همچنین رئال مادرید برنده بهترین باشگاه قرن از سوی فیفا شده‌است. همچنین کلمهٔ رئال در زبان اسپانیایی، به معنی «سلطنتی» است، این لقب را شاه آلفونسو سیزدهم در سال ۱۹۲۰ بر این تیم نهاد. همچنین در همان سال، شکل یک تاج نیز بر روی آرم این باشگاه قرار گرفت. رئال مادرید سال‌هاست که در لالیگا، از تیم‌های قدرتمند محسوب می‌شود و رقیب اصلی این تیم نیز، بارسلونا است. از نظر درآمد، رئال مادرید با ۵۵۷ میلیون یورو درآمد در فصل ۱۵–۲۰۱۴ در صدر پردرآمدترین باشگاه‌های فوتبال جهان بوده‌است." #@param {type:"string"}
question = "پایتخت اسپانیا کجاست؟" #@param {type:"string"}

preds = predictor([question], [context], batch_size=1)

print('\n\n Model Prediction: ', preds[0]['text'].strip())
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.90s/it]
#  Model Prediction:  مادرید

# %% [markdown]
# ## dataset

# %%
# !pip install -q datasets
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 27.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 15.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.3.1+cu121 requires nvidia-cublas-cu12==12.1.3.1; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cuda-cupti-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cuda-nvrtc-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cuda-runtime-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cudnn-cu12==8.9.2.26; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cufft-cu12==11.0.2.54; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-curand-cu12==10.3.2.106; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cusolver-cu12==11.4.5.107; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-nccl-cu12==2.20.5; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-nvtx-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# gcsfs 2024.6.1 requires fsspec==2024.6.1, but you have fsspec 2024.5.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.

# %%
from datasets import load_dataset
from transformers import TrainingArguments, Trainer

# %%
datasets = load_dataset("SajjadAyoubi/persian_qa")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading data:   0%|          | 0.00/1.62M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/165k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/9008 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/930 [00:00<?, ? examples/s]

# %%
datasets['validation'][8]
# Out:
# {'id': 9116,
#  'title': 'باشگاه فوتبال رئال مادرید',
#  'context': 'باشگاه فوتبال رئال مادرید یک باشگاه حرفه\u200cای فوتبال است که در مادرید، پایتخت اسپانیا قرار دارد. رئال موفق\u200cترین تیم تاریخ فوتبال اسپانیا و موفق\u200cترین تیم تاریخ فوتبال اروپا و موفق\u200cترین تیم فوتبال سدهٔ ۲۰ میلادی به انتخاب فیفا است. آن\u200cها دارای رکورد ۳۴ بار قهرمانی در لالیگا، ۱۹ قهرمانی در کوپا دل ری (جام حذفی)، ۱۰ سوپرکاپ اسپانیا، ۱۳ قهرمانی در لیگ قهرمانان اروپا، ۲ جام یوفا، ۴ سوپرکاپ اروپا و ۴ قهرمانی در جام باشگاه\u200cهای جهان هستند. رئال مادرید رکورددار قهرمانی در لیگ قهرمانان اروپا با ۱۳ قهرمانی و جام باشگاه های جهان با ۴ قهرمانی است. همچنین رئال مادرید برنده بهترین باشگاه قرن از سوی فیفا شده\u200cاست. همچنین کلمهٔ رئال در زبان اسپانیایی، به معنی «سلطنتی» است، این لقب را شاه آلفونسو سیزدهم در سال ۱۹۲۰ بر این تیم نهاد. همچنین در همان سال، شکل یک تاج نیز بر روی آرم این باشگاه قرار گرفت. رئال مادرید سال\u200cهاست که در لالیگا، از تیم\u200cهای قدرتمند محسوب می\u200cشود و رقیب اصلی این تیم نیز، بارسلونا است. از نظر درآمد، رئال مادرید با ۵۵۷ میلیون یورو درآمد در فصل ۱۵–۲۰۱۴ در صدر پردرآمدترین باشگاه\u200cهای فوتبال جهان بوده\u200cاست.',
#  'question': 'باشگاه فوتبال رئال مادرید در چه سالی تاسیس شده؟',
#  'answers': {'text': [], 'answer_start': []}}

# %%
datasets['validation'][10]['answers']['text']
# Out:
# ['بارسلونا', 'باشگاه فوتبال بارسلونا']

# %%
contexts = []
questions = []
answers = []
test_data = datasets['validation']
for p in test_data:
    if p['answers']['text']:
      contexts.append(p["context"])
      questions.append(p["question"])
      answers.append([p["answers"]["text"]][0])
answers[0]
# Out:
# ['مادرید', 'مادرید']

# %%
predictions = []
for question, context in zip(questions, contexts):
    preds = predictor([question.strip()], [context.strip()], batch_size=1)
    predictions.append(preds[0]['text'].strip())
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 30.60it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.14it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.00it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.34it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.86it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.41it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.43it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.38it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.26it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.64it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.97it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.92it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.42it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.26it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.09it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.50it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.66it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.53it/s]
# 100%|██████████| 1/1 [00:00<00:00, 40.71it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.86it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 52.30it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.50it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.44it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.77it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.46it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.43it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.12it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.81it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.96it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.60it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.42it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.12it/s]
# 100%|██████████| 1/1 [00:00<00:00, 52.98it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.71it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.16it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.90it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.16it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.23it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.73it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.21it/s]
# 100%|██████████| 1/1 [00:00<00:00, 52.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.14it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.52it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.43it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.23it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.49it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.50it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.86it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.96it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.49it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.14it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 52.65it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.49it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.34it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.57it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.16it/s]
# 100%|██████████| 1/1 [00:00<00:00, 52.14it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.65it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.20it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.16it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.42it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.84it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.01it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.94it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.56it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 44.56it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.80it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.09it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.71it/s]
# 100%|██████████| 1/1 [00:00<00:00, 44.65it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.70it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.71it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.03it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.47it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.09it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.22it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.42it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.39it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.03it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.38it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.68it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 24.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 40.97it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.04it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.90it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.68it/s]
# 100%|██████████| 1/1 [00:00<00:00, 40.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.48it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.05it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.94it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.68it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.77it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.98it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.71it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.50it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.64it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.14it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.30it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.60it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.38it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.60it/s]
# 100%|██████████| 1/1 [00:00<00:00, 52.86it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.76it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.29it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.52it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.26it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.56it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.81it/s]
# 100%|██████████| 1/1 [00:00<00:00, 42.30it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.26it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.80it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.29it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.92it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.16it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 42.70it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.58it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.60it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.96it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.81it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.32it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.84it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.91it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.60it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.20it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 42.66it/s]
# 100%|██████████| 1/1 [00:00<00:00, 42.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.86it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.68it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.65it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.15it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.37it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.39it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.97it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.86it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.98it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.67it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.34it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.18it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.64it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.63it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.17it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.54it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.56it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.88it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.81it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.58it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.83it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.98it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.51it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.19it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.98it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.90it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.57it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.38it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.29it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.67it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.63it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.83it/s]
# 100%|██████████| 1/1 [00:00<00:00, 42.66it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.42it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.64it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.99it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.42it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.76it/s]
# 100%|██████████| 1/1 [00:00<00:00, 44.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.41it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.19it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.52it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.34it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.96it/s]
# 100%|██████████| 1/1 [00:00<00:00, 44.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.05it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.80it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.94it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.16it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.42it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.85it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.81it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.71it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.81it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.02it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.42it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.30it/s]
# 100%|██████████| 1/1 [00:00<00:00, 40.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.67it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.41it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.13it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.28it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.99it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.48it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 42.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.02it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.32it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.65it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.14it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.05it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.85it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.88it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.78it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 24.70it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.94it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.02it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.01it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.22it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.22it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.39it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.02it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.63it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.41it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 40.90it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.98it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.76it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.20it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.57it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.21it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.43it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.70it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.42it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.97it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.86it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.48it/s]
# 100%|██████████| 1/1 [00:00<00:00, 42.14it/s]
# 100%|██████████| 1/1 [00:00<00:00, 40.76it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.32it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.51it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.03it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.42it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.20it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.83it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.78it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.18it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.00it/s]
# 100%|██████████| 1/1 [00:00<00:00, 44.97it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 44.92it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.18it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.64it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.97it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.51it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.77it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.32it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.29it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.48it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.23it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.48it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.66it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.17it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.86it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.54it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.15it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.98it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.66it/s]
# 100%|██████████| 1/1 [00:00<00:00, 44.16it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.14it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.11it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.90it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.52it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.97it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.77it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.96it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.19it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.85it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.56it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.38it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.28it/s]
# 100%|██████████| 1/1 [00:00<00:00, 44.60it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.78it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.86it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.86it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.03it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.66it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.22it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.56it/s]
# 100%|██████████| 1/1 [00:00<00:00, 53.05it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.67it/s]
# 100%|██████████| 1/1 [00:00<00:00, 40.98it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.66it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.14it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.60it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.53it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.18it/s]
# 100%|██████████| 1/1 [00:00<00:00, 23.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 40.21it/s]
# 100%|██████████| 1/1 [00:00<00:00, 40.01it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.20it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.38it/s]
# 100%|██████████| 1/1 [00:00<00:00, 42.51it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.03it/s]
# 100%|██████████| 1/1 [00:00<00:00, 40.65it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.85it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.91it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.59it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.99it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.80it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.56it/s]
# 100%|██████████| 1/1 [00:00<00:00, 22.71it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.15it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.92it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.98it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.39it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.13it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.42it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.84it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.37it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.68it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.73it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.90it/s]
# 100%|██████████| 1/1 [00:00<00:00, 42.05it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.26it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.53it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.49it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.11it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.59it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.12it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.47it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.21it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.22it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.83it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.21it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.97it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.23it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 42.42it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.73it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.44it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.80it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.21it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.83it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.18it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.78it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.84it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.92it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.78it/s]
# 100%|██████████| 1/1 [00:00<00:00, 40.23it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.81it/s]
# 100%|██████████| 1/1 [00:00<00:00, 44.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.19it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.88it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.63it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.78it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.43it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.23it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.05it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.90it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 42.68it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.03it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.70it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.42it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.11it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.72it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.34it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.46it/s]
# 100%|██████████| 1/1 [00:00<00:00, 40.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.52it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.63it/s]
# 100%|██████████| 1/1 [00:00<00:00, 40.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.46it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.43it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.72it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.50it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.03it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.54it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.04it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.15it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.48it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.90it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.23it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.47it/s]
# 100%|██████████| 1/1 [00:00<00:00, 40.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 44.03it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.59it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.66it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.70it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.37it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.65it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.34it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.49it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.03it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.47it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.80it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.43it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.99it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.85it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.57it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.57it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.05it/s]
# 100%|██████████| 1/1 [00:00<00:00, 40.78it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.28it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.63it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.67it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.76it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.43it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.17it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.64it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.28it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.40it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.99it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.03it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.71it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.97it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.34it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.83it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.46it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.49it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.34it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 40.40it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.54it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.70it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.23it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.68it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.97it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.28it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.68it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.73it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.58it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.02it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.15it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.66it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.44it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.46it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.59it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.51it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.49it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.54it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.14it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.41it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.02it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.41it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.73it/s]
# 100%|██████████| 1/1 [00:00<00:00, 40.92it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.56it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.50it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.39it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.04it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.52it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.49it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.01it/s]
# 100%|██████████| 1/1 [00:00<00:00, 44.13it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.26it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.05it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.41it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.03it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.72it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.85it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.03it/s]
# 100%|██████████| 1/1 [00:00<00:00, 44.70it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.37it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.50it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.16it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.02it/s]
# 100%|██████████| 1/1 [00:00<00:00, 42.48it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.90it/s]
# 100%|██████████| 1/1 [00:00<00:00, 44.20it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.97it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.63it/s]
# 100%|██████████| 1/1 [00:00<00:00, 40.86it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.17it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.71it/s]
# 100%|██████████| 1/1 [00:00<00:00, 44.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 44.90it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.88it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.97it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.99it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 42.67it/s]

# %%
predictions[0]
# Out:
# 'مادرید'

# %%
predictions[0] == answers[0][0]
# Out:
# True

# %%
len(predictions) == len(answers)
# Out:
# True

# %%
def exact_match(predictions, true_answers_list):
    matches = []
    for true_answers in true_answers_list:
        for answer in true_answers:
            if answer in predictions:
                matches.append(1)
                break
        else:
            matches.append(0)
    return sum(matches) / len(matches)


def f1_score(pred, true_answers):
    max_f1 = 0.0
    pred_tokens = pred.split()
    for true in true_answers:
        true_tokens = true.split()
        common_tokens = set(pred_tokens) & set(true_tokens)
        if not common_tokens:
            break
        precision = len(common_tokens) / len(pred_tokens)
        recall = len(common_tokens) / len(true_tokens)
        f1 = 2 * (precision * recall) / (precision + recall)
        if f1 > max_f1:
            max_f1 = f1
    return max_f1

em_score = exact_match(predictions, answers)
f1_scores = [f1_score(p, t) for p, t in zip(predictions, answers)]

average_f1_score = sum(f1_scores) / len(f1_scores)

print(f"Exact Match Score: {em_score}")
print(f"Average F1 Score: {average_f1_score}")
# Out:
# Exact Match Score: 0.5499231950844854
# Average F1 Score: 0.7482045143062575

# %% [markdown]
# ## Trainer

# %%
model_checkpoint = "pedramyazdipoor/persian_xlm_roberta_large"
max_length = 512 # The maximum length of a feature (question and context)
doc_stride = 256 # The authorized overlap between two part of the context when splitting it is needed.
batch_size = 4
lr = 3e-5
epoch = 2

# %%
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
# Out:
# tokenizer_config.json:   0%|          | 0.00/621 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]

# %%
def prepare_train_features(examples):
    tokenized_examples = tokenizer(
        examples["question"],
        examples["context"],
        truncation="only_second",
        max_length=max_length,
        stride=doc_stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,)

    sample_mapping = tokenized_examples.pop("overflow_to_sample_mapping")
    offset_mapping = tokenized_examples.pop("offset_mapping")
    tokenized_examples["start_positions"] = []
    tokenized_examples["end_positions"] = []
    for i, offsets in enumerate(offset_mapping):
        # We will label impossible answers with the index of the CLS token.
        input_ids = tokenized_examples["input_ids"][i]
        cls_index = input_ids.index(tokenizer.cls_token_id)
        # Grab the sequence corresponding to that example (to know what is the context and what is the question).
        sequence_ids = tokenized_examples.sequence_ids(i)
        # One example can give several spans, this is the index of the example containing this span of text.
        sample_index = sample_mapping[i]
        answers = examples["answers"][sample_index]
        # If no answers are given, set the cls_index as answer.
        if len(answers["answer_start"]) == 0:
            tokenized_examples["start_positions"].append(cls_index)
            tokenized_examples["end_positions"].append(cls_index)
        else:
            # Start/end character index of the answer in the text.
            start_char = answers["answer_start"][0]
            end_char = start_char + len(answers["text"][0])
            # Start token index of the current span in the text.
            token_start_index = 0
            while sequence_ids[token_start_index] != 1:
                token_start_index += 1
            # End token index of the current span in the text.
            token_end_index = len(input_ids) - 1
            while sequence_ids[token_end_index] != 1:
                token_end_index -= 1
            # Detect if the answer is out of the span (in which case this feature is labeled with the CLS index).
            if not (offsets[token_start_index][0] <= start_char and offsets[token_end_index][1] >= end_char):
                tokenized_examples["start_positions"].append(cls_index)
                tokenized_examples["end_positions"].append(cls_index)
            else:
                # Otherwise move the token_start_index and token_end_index to the two ends of the answer.
                # Note: we could go after the last offset if the answer is the last word (edge case).
                while token_start_index < len(offsets) and offsets[token_start_index][0] <= start_char:
                    token_start_index += 1
                tokenized_examples["start_positions"].append(token_start_index - 1)
                while offsets[token_end_index][1] >= end_char:
                    token_end_index -= 1
                tokenized_examples["end_positions"].append(token_end_index + 1)

    return tokenized_examples

# %%
# the datasets library does cashing itself, batched is multitreading for fast-tokenizer
tokenized_ds = datasets.map(prepare_train_features, batched=True, remove_columns=datasets["train"].column_names)
# Out:
# Map:   0%|          | 0/9008 [00:00<?, ? examples/s]
# Map:   0%|          | 0/930 [00:00<?, ? examples/s]

# %%
model = AutoModelForQuestionAnswering.from_pretrained(model_checkpoint)
# Out:
# config.json:   0%|          | 0.00/821 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.24G [00:00<?, ?B/s]

# %%
args = TrainingArguments(
    f"result",
    eval_strategy = "epoch",
    fp16=True,
    learning_rate=lr,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=epoch,
    weight_decay=0.0001,
    logging_dir='./logs',  # Directory for logging
    save_total_limit=1,  # Keep only the last checkpoint
    save_steps=1000,  # Save model every 1000 steps
    disable_tqdm=True,
    gradient_accumulation_steps = 8,
    warmup_ratio = 0.1,
    )

# %%
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=tokenized_ds['train'],
    eval_dataset=tokenized_ds['validation'],
    tokenizer=tokenizer)

# %%
torch.cuda.empty_cache()

# %%
# start training
trainer.train()
# Out:
# {'eval_loss': 1.0718482732772827, 'eval_runtime': 18.7885, 'eval_samples_per_second': 49.498, 'eval_steps_per_second': 12.401, 'epoch': 0.9995569339831635}
# {'loss': 1.1864, 'grad_norm': 29.18608856201172, 'learning_rate': 4.0828402366863906e-06, 'epoch': 1.7722640673460346}
# {'eval_loss': 1.0873653888702393, 'eval_runtime': 18.7526, 'eval_samples_per_second': 49.593, 'eval_steps_per_second': 12.425, 'epoch': 1.999113867966327}
# {'train_runtime': 1599.0719, 'train_samples_per_second': 11.292, 'train_steps_per_second': 0.353, 'train_loss': 1.1502347432129771, 'epoch': 1.999113867966327}
# TrainOutput(global_step=564, training_loss=1.1502347432129771, metrics={'train_runtime': 1599.0719, 'train_samples_per_second': 11.292, 'train_steps_per_second': 0.353, 'train_loss': 1.1502347432129771, 'epoch': 1.999113867966327})

# %%
predictor = AnswerPredictor(model, tokenizer, device='cuda', n_best=10, no_answer=True)

# %%
predictions = []
for question, context in zip(questions, contexts):
    preds = predictor([question], [context], batch_size=1)
    predictions.append(preds[0]['text'].strip())
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 32.92it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.34it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.68it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.22it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.26it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.17it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.85it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.77it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.72it/s]
# 100%|██████████| 1/1 [00:00<00:00, 24.86it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.66it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.01it/s]
# 100%|██████████| 1/1 [00:00<00:00, 23.63it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.01it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.05it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.63it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.21it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.71it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.88it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.20it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.49it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.92it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.50it/s]
# 100%|██████████| 1/1 [00:00<00:00, 21.39it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.23it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.80it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.11it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.57it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.09it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.66it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.98it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.53it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.59it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.42it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.90it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.30it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.65it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.78it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.13it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.03it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.73it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.56it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.17it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.39it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.58it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.00it/s]
# 100%|██████████| 1/1 [00:00<00:00, 23.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.72it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.72it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.88it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.60it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.47it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.05it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.04it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.72it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.77it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.80it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.85it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.13it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.02it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.94it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.50it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.94it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.17it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.00it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.17it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.32it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.98it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.41it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.18it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.78it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.60it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.00it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.57it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.23it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.20it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.78it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.92it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.30it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.81it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 22.28it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.05it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.72it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.30it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.40it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.29it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.81it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.54it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.34it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.53it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.66it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.49it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.04it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.86it/s]
# 100%|██████████| 1/1 [00:00<00:00, 23.67it/s]
# 100%|██████████| 1/1 [00:00<00:00, 24.67it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.34it/s]
# 100%|██████████| 1/1 [00:00<00:00, 23.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.37it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 24.16it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.88it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.53it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.64it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.76it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 23.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.39it/s]
# 100%|██████████| 1/1 [00:00<00:00, 22.46it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.38it/s]
# 100%|██████████| 1/1 [00:00<00:00, 23.40it/s]
# 100%|██████████| 1/1 [00:00<00:00, 22.68it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.34it/s]
# 100%|██████████| 1/1 [00:00<00:00, 23.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 17.65it/s]
# 100%|██████████| 1/1 [00:00<00:00, 21.58it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.98it/s]
# 100%|██████████| 1/1 [00:00<00:00, 18.46it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 22.76it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.63it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.85it/s]
# 100%|██████████| 1/1 [00:00<00:00, 23.26it/s]
# 100%|██████████| 1/1 [00:00<00:00, 24.34it/s]
# 100%|██████████| 1/1 [00:00<00:00, 20.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.09it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.13it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.57it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.12it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.17it/s]
# 100%|██████████| 1/1 [00:00<00:00, 24.30it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.83it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.67it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.49it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.99it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.56it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.84it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.48it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.77it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.71it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.46it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.43it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.63it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.77it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.98it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.11it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.77it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.32it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.86it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.90it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.47it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.20it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.00it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.50it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.54it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.83it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.73it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.17it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.00it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.99it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.53it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.68it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.76it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.39it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.59it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.22it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.53it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.03it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.44it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.52it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.30it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.26it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.39it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.39it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.29it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.29it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.57it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.72it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.88it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.66it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.26it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.00it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.71it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.52it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.73it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.43it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.40it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.56it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.53it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.94it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.78it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.85it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.21it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.18it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.83it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.02it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.12it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.80it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.02it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.63it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.05it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.21it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.34it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.00it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.51it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.52it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.59it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.80it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.01it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.48it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.50it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.99it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.51it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.58it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.77it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.39it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.64it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.02it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.22it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.04it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.44it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.19it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.86it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.19it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.76it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.78it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.34it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.09it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.81it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.12it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.19it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.17it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.63it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.58it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.68it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.68it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.59it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.11it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.58it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.28it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.47it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.30it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.39it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.99it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.13it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.44it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.29it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.80it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 19.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 18.80it/s]
# 100%|██████████| 1/1 [00:00<00:00, 22.90it/s]
# 100%|██████████| 1/1 [00:00<00:00, 18.41it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.00it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.83it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.88it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.44it/s]
# 100%|██████████| 1/1 [00:00<00:00, 22.64it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.83it/s]
# 100%|██████████| 1/1 [00:00<00:00, 24.83it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.92it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.39it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.16it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.46it/s]
# 100%|██████████| 1/1 [00:00<00:00, 24.03it/s]
# 100%|██████████| 1/1 [00:00<00:00, 19.91it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.57it/s]
# 100%|██████████| 1/1 [00:00<00:00, 24.88it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.91it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.98it/s]
# 100%|██████████| 1/1 [00:00<00:00, 19.68it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.22it/s]
# 100%|██████████| 1/1 [00:00<00:00, 18.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 23.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.46it/s]
# 100%|██████████| 1/1 [00:00<00:00, 23.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 21.70it/s]
# 100%|██████████| 1/1 [00:00<00:00, 19.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.26it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 21.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 22.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 22.20it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.73it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.86it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.37it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.57it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.50it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.46it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.04it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.30it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.54it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.58it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.48it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.28it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.14it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.26it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.44it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.70it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.15it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.88it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.32it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.41it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.71it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.40it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.18it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.59it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.32it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.44it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.32it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.70it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.00it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.40it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.48it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.23it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.22it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.16it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.26it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.09it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.91it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.78it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.15it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.81it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.17it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.65it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.73it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.56it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.97it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.44it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.52it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.29it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.40it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.43it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.76it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.91it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.91it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.05it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.05it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.92it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.14it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.42it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.02it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.05it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.98it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.34it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.19it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.21it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.94it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.29it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.37it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.80it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.41it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.43it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.50it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.56it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.64it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.78it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.57it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.43it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.29it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.37it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.46it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.86it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.68it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.22it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 24.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.65it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.80it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.96it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.43it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.81it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.92it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.16it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.23it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.68it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.57it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.71it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 24.88it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.88it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.99it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.26it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.28it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.97it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.96it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.17it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.97it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.22it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.78it/s]
# 100%|██████████| 1/1 [00:00<00:00, 21.84it/s]
# 100%|██████████| 1/1 [00:00<00:00, 24.64it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.16it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.73it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.38it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.63it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.98it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.99it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.22it/s]
# 100%|██████████| 1/1 [00:00<00:00, 20.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 23.18it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.19it/s]
# 100%|██████████| 1/1 [00:00<00:00, 24.18it/s]
# 100%|██████████| 1/1 [00:00<00:00, 23.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 20.68it/s]
# 100%|██████████| 1/1 [00:00<00:00, 24.83it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.76it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.91it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 24.46it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.44it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.04it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.99it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.43it/s]
# 100%|██████████| 1/1 [00:00<00:00, 21.54it/s]
# 100%|██████████| 1/1 [00:00<00:00, 22.12it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.81it/s]
# 100%|██████████| 1/1 [00:00<00:00, 22.85it/s]
# 100%|██████████| 1/1 [00:00<00:00, 24.20it/s]
# 100%|██████████| 1/1 [00:00<00:00, 22.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.44it/s]
# 100%|██████████| 1/1 [00:00<00:00, 23.70it/s]
# 100%|██████████| 1/1 [00:00<00:00, 24.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.26it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.64it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 23.84it/s]
# 100%|██████████| 1/1 [00:00<00:00, 22.67it/s]
# 100%|██████████| 1/1 [00:00<00:00, 21.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.76it/s]
# 100%|██████████| 1/1 [00:00<00:00, 22.86it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.42it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.04it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.98it/s]
# 100%|██████████| 1/1 [00:00<00:00, 23.56it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.91it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 23.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 21.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.56it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.29it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.30it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.97it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.77it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.40it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.21it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.80it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.77it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.20it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.23it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.85it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.11it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.28it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.86it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.78it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.49it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.14it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.02it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 31.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.56it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.60it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.17it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.02it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.00it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.02it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.12it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.20it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.67it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.88it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.48it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.65it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.59it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.22it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.44it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.17it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.78it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.19it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.65it/s]
# 100%|██████████| 1/1 [00:00<00:00, 21.18it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.58it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.57it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.68it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.29it/s]

# %%
# cleaner function
import re
def cleaner(text):
    return re.sub('\u200c', " ", text).strip()

# %%
def normalize(s):
    """Removing articles and punctuation, and standardizing whitespace are all typical text processing steps."""
    import string, re
    def cleaner(text):
        return re.sub('\u200c', " ", text).strip()
    def remove_articles(text):
        regex = re.compile(r"\b(a|an|the)\b", re.UNICODE)
        return re.sub(regex, " ", text)

    def white_space_fix(text):
        return " ".join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return "".join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punc(lower(cleaner(s)))))

# %%
def exact_match(predictions, true_answers_list):
    matches = []
    for i in range(len(predictions)):
        if normalize(true_answers_list[i][0]) == normalize(predictions[i]) or normalize(true_answers_list[i][1]) == normalize(predictions[i]) :
          matches.append(1)
        else:
          print(answers[i])
          print(predictions[i])
          print("------------")
          matches.append(0)
    return sum(matches) / len(matches)


def f1_score(pred, true_answers):
    max_f1 = 0.0
    pred_tokens = pred.split()
    for true in true_answers:
        true_tokens = true.split()
        common_tokens = set(pred_tokens) & set(true_tokens)
        if not common_tokens:
            break
        precision = len(common_tokens) / len(pred_tokens)
        recall = len(common_tokens) / len(true_tokens)
        f1 = 2 * (precision * recall) / (precision + recall)
        if f1 > max_f1:
            max_f1 = f1
    return max_f1

def exact_match2(predictions, true_answers_list):
    matches = []
    for i in range(len(predictions)):
        if true_answers_list[i][0] in predictions[i] or true_answers_list[i][1] in predictions[i] :
          matches.append(1)
        else:
          matches.append(0)
    return sum(matches) / len(matches)

em_score = exact_match(predictions, answers)
include = exact_match2(predictions, answers)
f1_scores = [f1_score(p, t) for p, t in zip(predictions, answers)]

average_f1_score = sum(f1_scores) / len(f1_scores)
# Out:
# ['مادرید', 'مادرید']
# رئال مادرید
# ------------
# ['۱۳', '۱۳']
# ۱۳ قهرمانی در لیگ قهرمانان اروپا، ۲ جام یوفا، ۴ سوپرکاپ اروپا و ۴ قهرمانی در جام باشگاه‌های جهان هستند. رئال مادرید رکورددار قهرمانی در لیگ قهرمانان اروپا با ۱۳
# ------------
# ['شاه آلفونسو سیزدهم در سال ۱۹۲۰ بر این تیم نهاد', 'شاه آلفونسو سیزدهم']
# کلمهٔ رئال در زبان اسپانیایی، به معنی «سلطنتی» است، این لقب را شاه آلفونسو سیزدهم در سال ۱۹۲۰ بر این تیم نهاد.
# ------------
# ['به نوعی، نهادی برای ترویج فرهنگ کاتالان و کاتالانیسم', 'نهادی برای ترویج فرهنگ کاتالان و کاتالانیسم']
# بارسا به نوعی، نهادی برای ترویج فرهنگ کاتالان و کاتالانیسم است
# ------------
# ['تهران', 'تهران']
#
# ------------
# ['رهبر سیاسی و معنوی هندی\u200cها', 'رهبر سیاسی و معنوی هندی\u200cها بود']
# رهبر سیاسی و معنوی هندی‌ها بود که ملت هند را در راه آزادی از استعمار امپراتوری بریتانیا رهبری کرد.
# ------------
# ['در سال ۱۹۱۸', '۱۹۱۸']
# از زمانی که وی مسئولیت رهبری نبرد برای آزادی و کنگره ملی هند در سال ۱۹۱۸ را به عهده گرفت
# ------------
# ['قورباغه\u200cها بدن نرم و مرطوب دارند و در نزدیکی آب\u200cها زندگی می\u200cکنند. وزغها اما پوست خشک و زگیل مانند دارند و عمدتاً روی خشکی زندگی می\u200cکنند', 'قورباغه\u200cها بدن نرم و مرطوب دارند و در نزدیکی آب\u200cها زندگی می\u200cکنند. وزغها اما پوست خشک و زگیل مانند دارند و عمدتاً روی خشکی']
#
# ------------
# ['در نزدیکی آب\u200cها', 'نزدیکی آب\u200cها']
# در اغلب مناطق جهان زیستگاه قورباغه‌ها گسترده شده‌است، بااین‌حال آن‌ها در قطب جنوب و و در بسیاری از جزایر اقیانوسی حضور ندارند.
# ------------
# ['خشک و زگیل مانند', 'خشک و زگیل مانند']
# پوست خشک و زگیل مانند
# ------------
# ['قطب جنوب و و در بسیاری از جزایر اقیانوسی', 'قطب جنوب و و در بسیاری از جزایر اقیانوسی']
# در قطب جنوب و و در بسیاری از جزایر اقیانوسی
# ------------
# ['احتمالاً بین سال\u200cهای ۶۶ تا ۱۱۰ میلادی', 'سال\u200cهای ۶۶ تا ۱۱۰']
# بین سال‌های ۶۶ تا ۱۱۰ میلادی
# ------------
# ['مشخص نیست', 'مشخص نیست']
#
# ------------
# ['به پیمانی اشاره دارد که آغازگر دورهٔ جدیدی از ارتباط خداوند با انسان است', 'آغازگر دورهٔ جدیدی از ارتباط خداوند با انسان']
# نام این بخش به پیمانی اشاره دارد که آغازگر دورهٔ جدیدی از ارتباط خداوند با انسان است
# ------------
# ['نوعی کانی آهن', 'نوعی کانی آهن']
# نوعی کانی آهن است
# ------------
# ['قُطب\u200cنما وسیله\u200cای برای تعیین جهت (جهت\u200cیابی)', 'برای تعیین جهت']
# تعیین جهت (جهت‌یابی)
# ------------
# ['برای تعیین جهت (جهت\u200cیابی)', 'جهت\u200cیابی']
# تعیین جهت (جهت‌یابی)
# ------------
# ['طبیعی', 'آهنرباهای طبیعی']
# نوعی کانی آهن
# ------------
# ['نیروی آهنربایی زمین', 'نیروی آهنربایی زمین']
# میدان مغناطیسی زمین
# ------------
# ['دستگاه ثبت اطلاعات فنی پرواز و دستگاه ثبت صداهای کابین', 'دستگاه ثبت اطلاعات فنی پرواز و دستگاه ثبت صداهای کابین']
# دستگاه ثبت اطلاعات فنی پرواز و دستگاه ثبت صداهای کابین و هواپیما
# ------------
# ['در پیدا کردن جعبه سیاه', 'پیدا کردن جعبه سیاه']
# در هنگام سقوط هواپیما در آب
# ------------
# ['برای ضبط چگونگی چرخش پره\u200cهای ملخ', 'ضبط چگونگی چرخش پره\u200cهای ملخ']
# آن‌ها از وسیله‌ای برای ضبط چگونگی چرخش پره‌های ملخ
# ------------
# ['اکنش\u200cهای شیمیایی مختلف و گرمازا', 'واکنش\u200cهای شیمیایی مختلف و گرمازا، واکنش\u200cهای هسته\u200cای']
# واکنش‌های شیمیایی مختلف و گرمازا، واکنش‌های هسته‌ای مانند شکافت هسته‌ای یا گداخت هسته‌ای
# ------------
# ['باب ۱۱–۱۴ تا ۱۹', 'باب ۱۱–۱۴ تا ۱۹']
# در باب ۱۱–۱۴ تا ۱۹
# ------------
# ['برادرزادهٔ ابراهیم', 'عمویش ابراهیم']
# برادرزادهٔ
# ------------
# ['پدربزرگ لوط، تارح، او را به سرپرستی گرفت', 'تارح، او را به سرپرستی گرفت']
#
# ------------
# ['قصد تجاوز به مهمانان لوط را داشتند', 'قصد تجاوز به مهمانان لوط']
# زیرا قصد تجاوز به مهمانان لوط را داشتند
# ------------
# ['بلندمرتبه\u200cترین زن عالم به شمار می\u200cرود و تنها زنی است که نامش در قرآن ذکر شده', 'بلندمرتبه\u200cترین زن عالم']
# در اسلام مریم بلندمرتبه‌ترین زن عالم به شمار می‌رود و تنها زنی است که نامش در قرآن ذکر شده.
# ------------
# ['والا', 'والا']
# کاتولیک‌ها برای مریم به عنوان مادر خدا جایگاهی والا قائل هستند
# ------------
# ['آماده\u200cسازی مواد برای بهره بری دوباره', 'آماده\u200cسازی مواد برای بهره بری دوباره']
# به آماده‌سازی مواد برای بهره بری دوباره گفته می‌شود.
# ------------
# ['کاهش می\u200cدهد.', 'کاهش']
# بازیافت از هدر رفتن منابع سودمند و سرمایه‌های ملی جلوگیری می‌کند و مصرف مواد خام و مصرف انرژی را کاهش می‌دهد
# ------------
# ['تولید گازهای گلخانه\u200cای نیز کاهش می\u200cیابد', 'تولید گازهای گلخانه\u200cای نیز کاهش می\u200cیابد']
# بازیافت از هدر رفتن منابع سودمند و سرمایه‌های ملی جلوگیری می‌کند و مصرف مواد خام و مصرف انرژی را کاهش می‌دهد. با این کار، تولید گازهای گلخانه‌ای نیز کاهش می‌یابد.
# ------------
# ['کتاب ارداویراف\u200cنامه', 'کتاب ارداویراف\u200cنامه']
# ارداویراف‌نامه
# ------------
# ['دومین یکپارچه\u200cسازی بزرگ در فیزیک', 'دومین یکپارچه\u200cسازی بزرگ']
# دومین یکپارچه‌سازی بزرگ در فیزیک، پس از نخستین آن که از سوی نیوتن انجام گرفت، به‌شمار می‌رود.
# ------------
# ['فرمول\u200cبندی نظریه کلاسیک امواج الکترومغناطیسی', 'نظریه کلاسیک امواج الکترومغناطیسی']
# فرمول‌بندی نظریه کلاسیک امواج الکترومغناطیسی و گردآوردن الکتریسیته، مغناطیس و نور برای نخستین بار در کنار هم، به عنوان جلوه‌هایی از یک پدیده، اشاره
# ------------
# ['استاد علوم طبیعی در دانشگاه اسکاتلند و سپس کمبریج', 'دانشگاه اسکاتلند و سپس کمبریج']
# دانشگاه ادینبورگ و کمبریج
# ------------
# ['لئوپولد پنجم', 'لئوپولد پنجم']
# لئوپولد پنجم، دوک اتریش
# ------------
# ['اوگوست', 'ستایششده']
#
# ------------
# ['تیری زهرآلود', 'تیری زهرآلود']
#
# ------------
# ['ناحیه بین رود وُلگا و دشت\u200cهای مجارستان', 'هون\u200cها در ناحیه بین رود وُلگا و دشت\u200cهای مجارستان می\u200cزیستند']
# هون‌ها در ناحیه بین رود وُلگا و دشت‌های مجارستان
# ------------
# ['زرد رنگتر از بیشتر افراد قومش بود', 'زرد رنگتر از بیشتر افراد قومش بود']
# آتیلا، زرد رنگتر از بیشتر افراد قومش بود
# ------------
# ['واقع در لبنان امروزی', 'لبنان']
# لبنان امروزی
# ------------
# ['در آن زمان کودک بود و در دمشق زندگی می\u200cکرد', 'در آن زمان کودک بود']
# صلاح‌الدین، که در آن زمان کودک بود و در دمشق زندگی می‌کرد
# ------------
# ['در درون شهر رم در کشور ایتالیا جای دارد', 'درون شهر رم در کشور ایتالیا']
# در درون شهر رم در کشور ایتالیا
# ------------
# ['پاپ، رهبر کاتولیک\u200cهای جهان', 'پاپ']
# پاپ، رهبر کاتولیک‌های جهان و مرکز کلیسای کاتولیک
# ------------
# ['بنیتو موسولینی نخست\u200cوزیر ایتالیا', 'بنیتو موسولینی']
#
# ------------
# ['یک یا چند نوع خاص از وابستگی', 'وابستگی']
# توسط یک یا چند نوع خاص از وابستگی مانند ایده‌ها و تبادلات مالی، دوستان، خویشاوندان، لینک‌های وب، و سرایت بیماری‌ها
# ------------
# ['بازیگران فردی درون شبکه\u200cها', 'بازیگران فردی درون شبکه\u200cها']
# رأس‌ها، بازیگران فردی درون شبکه‌ها و یال‌ها، روابط میان این بازیگران هستند.
# ------------
# ['یال\u200cها', 'یال\u200c']
#
# ------------
# ['اشاره ضمنی به مجموعه روابط پیچیده میان افراد در سیستم\u200cهای اجتماعی', 'اشاره ضمنی به مجموعه روابط پیچیده میان افراد در سیستم\u200cهای اجتماعی']
# برای اشاره ضمنی به مجموعه روابط پیچیده میان افراد در سیستم‌های اجتماعی در تمامی مقیاس‌ها از روابط بین فردی گرفته تا بین‌المللی
# ------------
# ['مرگ', 'مرگ']
# تلاش و مبارزه هری برای غلبه بر جادوگر سیاه، لرد ولدمورت
# ------------
# ['به ۸۳ زبان دنیا ترجمه شده\u200c', '۸۳ زبان']
# به ۸۳ زبان دنیا ترجمه شده‌است.
# ------------
# ['یک مجله خبری هفته\u200cنامه و روزنامه آنلاین آمریکایی', 'مجله خبری هفته\u200cنامه و روزنامه آنلاین آمریکایی']
# یک مجله خبری هفته‌نامه و روزنامه آنلاین آمریکایی است
# ------------
# ['توسط سیاهرگ باب کبدی', 'سیاهرگ باب کبدی']
# تمام خون دستگاه گوارش توسط سیاهرگ باب کبدی جمع‌آوری شده و وارد جگر می‌شود
# ------------
# ['تصفیهٔ', 'تبدیل کردنشان به مواد بی\u200cضرر']
# به دام انداختن سموم و تصفیهٔ آن‌ها با تبدیل کردنشان به مواد بی‌ضرر
# ------------
# ['با یک راکت، توپ تنیس', 'راکت، توپ تنیس']
# راکت
# ------------
# ['بین دو نفر (سینگل) یا بین دو تیم دونفره', 'بین دو نفر (سینگل) یا بین دو تیم دونفره (دوبل)']
# دو نفر
# ------------
# ['در بریتانیا', 'در بریتانیا و بیشتر میان اشراف\u200cزادگان']
# بریتانیا
# ------------
# ['به دلیل تجهیزات گران\u200cقیمت و زمین مناسب', 'تجهیزات گران\u200cقیمت و زمین مناسب']
# تجهیزات گران‌قیمت و زمین مناسب برای انجام این ورزش
# ------------
# ['دو تیم شش نفره', 'دو تیم شش نفره']
# شش نفره
# ------------
# ['طول زمین والیبال ۱۸ متر و عرض آن ۹', '۱۸ متر و عرض آن ۹']
# طول زمین والیبال ۱۸ متر و عرض آن ۹ است.
# ------------
# ['۳ ست (یا دست) از ۵ پنج ست', '۳ ست (یا دست)']
# هرتیم حداقل باید ۳ ست (یا دست)
# ------------
# ['در سال ۱۸۹۵ در ایالات متحده آمریکا', 'در سال ۱۸۹۵']
# والیبال در سال ۱۸۹۵ در ایالات متحده آمریکا و توسط ویلیام مورگان
# ------------
# ['در ایالات متحده آمریکا و توسط ویلیام مورگان', 'توسط ویلیام مورگان']
# ویلیام مورگان
# ------------
# ['تمام گروه\u200cهای سنی', 'برای تمام گروه\u200cهای سنی']
# این رشته تقریباً برای تمام گروه‌های سنی مناسب است
# ------------
# ['از روستای مهرآباد جنوبی', 'روستای مهرآباد جنوبی ده بالا']
# از روستای مهرآباد جنوبی ده بالا
# ------------
# ['شهر تهران', 'تهران']
# در بخش غربی تهران
# ------------
# ['بخش غربی تهران', 'بخش غربی تهران']
# در بخش غربی تهران واقع شده
# ------------
# ['۳۰ کیلومتری تهران بزرگ', '۳۰ کیلومتری تهران']
# در ۳۰ کیلومتری تهران بزرگ ، در حوزه اداری و سیاسی شهرری (بخش فشافویه ری) تهران میان آزادراه تهران-قم در یک سایت ۱۴ هزار هکتاری قرار گرفته‌است.
# ------------
# ['۱۳۵۱', '۱۳۵۱ و با نام «فرودگاه بین\u200cالمللی آریامهر»']
# ۱۳۴۶
# ------------
# ['۱۴ هزار هکتار', '۱۴ هزار']
# ۱۴ هزار هکتاری
# ------------
# ['در شهر کرمان', 'کرمان']
# شهر کرمان
# ------------
# ['۲۰ مقصد، در اروپا، آسیا و خاورمیانه', '۲۰ مقصد']
# روزانه به ۲۰ مقصد
# ------------
# ['فرودگاه امام خمینی', 'فرودگاه امام خمینی']
# فرودگاه امام خمینی تهران
# ------------
# ['۲٬۹۰۰ هکتار', '۲٬۹۰۰ هکتار']
# ۲٬۹۰۰ هکتار (۷٬۲۰۰ جریب فرنگی)
# ------------
# ['هواپیمایی امارات', 'هواپیمایی امارات']
# قطب هواپیمایی امارات
# ------------
# ['الگوریتم', 'با استفاده از یک الگوریتم']
# یک الگوریتم
# ------------
# ['روند رمز کردن پیام\u200cها یا اطلاعات', 'رمز کردن پیام\u200cها یا اطلاعات']
# روند رمز کردن پیام‌ها یا اطلاعات است به گونه ای که تنها افراد مجاز قادر به خواندن آن باشند
# ------------
# ['۱۸۸۶', '۱۸۸۶']
# در سال ۱۸۸۶
# ------------
# ['دوک باکینگهام', 'دوک باکینگهام']
# خانواده سلطنتی بریتانیا
# ------------
# ['جان نش و ادوارد بلور', 'جان نش و ادوارد بلور']
# دو معمار به نام‌های جان نش و ادوارد بلور
# ------------
# ['رویدادهای عمومی ویژه و مهمانی\u200cهای سلطنتی', 'رویدادهای عمومی ویژه']
# مرکز رویدادهای عمومی ویژه و مهمانی‌های سلطنتی
# ------------
# ['سال ۱۹۳۷ توسط کیشیرو تویودا', 'سال ۱۹۳۷']
# در سال ۱۹۳۷
# ------------
# ['کارخانه شرکت نساجی صنایع تویوتا', 'شرکت نساجی صنایع تویوتا']
# در کارخانه شرکت نساجی صنایع تویوتا
# ------------
# ['استان آیچی ژاپن', 'ژاپن']
# شهر تویوتا در استان آیچی ژاپن
# ------------
# ['تویوتا ای\u200cای', 'ای\u200cای']
# نخستین خودروی سواری این شرکت تویوتا ای‌ای نام داشت.
# ------------
# ['ساکیشی تویودا', 'ساکیشی تویودا']
# کیشیرو تویودا
# ------------
# ['اکثر تورنمنت\u200cهای بین\u200cالمللی فوتبال', 'تورنمنت\u200cهای بین\u200cالمللی فوتبال']
# جام جهانی فوتبال
# ------------
# ['۲۱ می۱۹۰۴', '۱۹۰۴']
# در ۲۱ می۱۹۰۴
# ------------
# ['در ۱۱ دسامبر ۱۹۴۶', '۱۱ دسامبر ۱۹۴۶']
# در ۱۱ دسامبر ۱۹۴۶ به توصیه شورای اقتصادی و اجتماعی ملل متحد و تصویب مجمع عمومی سازمان ملل متحد برپا شد.
# ------------
# ['۱۹۳ کشور عضو رسمی و ۱۱ عضو وابسته', '۱۹۳ کشور عضو رسمی و ۱۱ عضو وابسته']
# یونسکو ۱۹۳ کشور عضو رسمی و ۱۱ عضو وابسته دارد.
# ------------
# ['ایجاد فرهنگ صلح و دانش فراگیر', 'ایجاد فرهنگ صلح و دانش']
# ایجاد فرهنگ صلح و دانش فراگیر از طریق اطلاعات و ارتباطات
# ------------
# ['آموزش، علوم، فرهنگ، ارتباطات و اطلاعات', 'از طریق آموزش، علوم، فرهنگ، ارتباطات و اطلاعات']
# آموزش، علوم طبیعی، علوم اجتماعی / انسانی، فرهنگ و ارتباطات / اطلاعات
# ------------
# ['آموزش برای همه و علم\u200cآموزی تمام عمر', 'آموزش برای همه']
# جنبش آموزش برای همه و علم‌آموزی تمام عمر
# ------------
# ['ایجاد صلح، ریشه کن کردن فقر، توسعه پایدار', 'ایجاد صلح، ریشه کن کردن فقر']
# ایجاد صلح، ریشه کن کردن فقر، توسعه پایدار و گفتگوی بین فرهنگی
# ------------
# ['ورزشی', 'بازی\u200cهای ورزشی']
# بازی‌های ورزشی (که توسط بخش ای‌ای اسپورتز، وابسته به این شرکت تولید می‌شود)، بازی‌های برگرفته از فیلم‌های محبوب و البته بازی‌های معروفی
# ------------
# ['با مشارکت بیش از ۱۵ کشور', 'بیش از ۱۵ کشور']
#
# ------------
# ['در ارتفاع ۳۳۰ تا ۴۳۵ کیلومتری از سطح زمین', 'در مدار نزدیک زمین']
# در مدار نزدیک زمین و در ارتفاع ۳۳۰ تا ۴۳۵ کیلومتری از سطح زمین در حرکت است.
# ------------
# ['۲۷٬۶۰۰ کیلومتر بر ساعت', '۲۷٬۶۰۰ کیلومتر']
# سرعت آن در مدار برابر ۲۷٬۶۰۰ کیلومتر بر ساعت
# ------------
# ['۱۵/۵ مرتبه', '۱۵/۵']
# هر ۹۳ دقیقه یک مرتبه به دور زمین می‌چرخد
# ------------
# ['چشم غیرمسلح', 'چشم غیرمسلح']
# با چشم غیرمسلح
# ------------
# ['فضای کار، پژوهش و زندگی', '۱۲۰۰ متر مکعب فضای کار']
# ۱۲۰۰ متر مکعب فضای کار، پژوهش و زندگی
# ------------
# ['جنگ سرد و اوج رقابت\u200cهای فضایی', 'جنگ سرد']
# به زمان جنگ سرد و اوج رقابت‌های فضایی
# ------------
# ['دنباله\u200cای از نوکلوئوتیدهاست', 'دنباله\u200cای از نوکلوئوتیدهاست']
# دنباله‌ای از نوکلوئوتیدهاست که در برگیرنده اطلاعات لازم جهت تولید مولوکول‌های RNA و یا پروتئین‌های لازم برای سلول هستند.
# ------------
# ['تولید مولوکول\u200cهای RNA و یا پروتئین\u200cهای لازم برای سلول', 'تولید مولوکول\u200cهای RNA و یا پروتئین\u200cهای لازم برای سلول']
# جهت تولید مولوکول‌های RNA و یا پروتئین‌های لازم برای سلول
# ------------
# ['جهش\u200cهای ژنتیکی', 'انتخاب طبیعی']
# در اثر جهش‌های ژنتیکی، براساس انتخاب طبیعی
# ------------
# ['در ایالت کنتاکی', 'ایالت کنتاکی']
# یک کلبه چوبی واقع در ایالت کنتاکی
# ------------
# ['حزب جمهوری\u200cخواه', 'جمهوری\u200cخواه']
# حزب ویگ
# ------------
# ['سال ۱۸۶۱', '۱۸۶۱']
# از سال ۱۸۶۱
# ------------
# ['سال\u200cهای ۲۰۰۴ و ۲۰۰۵', '۲۰۰۴ و ۲۰۰۵']
# در سال‌های ۲۰۰۴
# ------------
# ['حکیم ابوالقاسم فردوسی توسی', 'فردوسی']
#
# ------------
# ['افسانه\u200cها و تاریخ ایران', 'افسانه\u200cها']
# افسانه‌ها و تاریخ ایران از آغاز تا حملهٔ عرب‌ها به ایران در سدهٔ هفتم میلادی
# ------------
# ['حملهٔ عرب\u200cها به ایران در سدهٔ هفتم میلادی', 'حملهٔ عرب\u200cها به ایران']
# از آغاز تا حملهٔ عرب‌ها به ایران در سدهٔ هفتم میلادی
# ------------
# ['کهکشان\u200cهای ناهمگون یا بی\u200cقاعده هیچ شکل یا ساختار سامان\u200cمندی ندارند', 'ناهمگون یا بی\u200cقاعده']
# کهکشان‌های ناهمگون یا بی‌قاعده هیچ شکل یا ساختار سامان‌مندی ندارند، آن‌ها دارای جرم بیشتری از کهکشان‌های دیگر هستند و بیشتر ستاره‌های موجود در آن‌ها دارای طول عمر کم و درخشان می‌باشند
# ------------
# ['دارای طول عمر کم و درخشان', 'طول عمر کم و درخشان']
# دارای جرم بیشتری از کهکشان‌های دیگر هستند و بیشتر ستاره‌های موجود در آن‌ها دارای طول عمر کم و درخشان می‌باشند
# ------------
# ['پزشک و جراح مغز و اعصاب', 'پزشک و جراح مغز و اعصاب']
# پزشک و جراح مغز و اعصاب ایرانی
# ------------
# ['ریاست بیمارستان خصوصی علوم عصبی هانوفر', 'ریاست بیمارستان خصوصی علوم عصبی هانوفر']
# ریاست بیمارستان خصوصی علوم عصبی هانوفر در آلمان را بر عهده دارد
# ------------
# ['مجید سمیعی', 'مجید سمیعی']
# خود بنیان‌گذار آن بوده‌است.
# ------------
# ['پرندگان', 'پرندگان']
#
# ------------
# ['جانورانی تنبل، خنگ و خون\u200cسرد', 'تنبل، خنگ و خون\u200cسرد']
# دانشمندان دایناسورها را جانورانی تنبل، خنگ و خون‌سرد به‌شمار می‌آوردند
# ------------
# ['سدهٔ نوزدهم میلادی', 'سدهٔ نوزدهم میلادی']
# در سدهٔ نوزدهم میلادی
# ------------
# ['اشاره کردن به «تبار جدا یا از زیرراسته خزندگان سوسماری»', 'تبار جدا یا از زیرراسته خزندگان سوسماری']
# برای اشاره کردن به «تبار جدا یا از زیرراسته خزندگان سوسماری»
# ------------
# ['دانشکده فنی دانشگاه تهران', 'دانشکده فنی دانشگاه تهران']
# دانشگاه تهران
# ------------
# ['مهندس بازرگان', 'مهدی بازرگان تبریزی']
# مهدی بازرگان
# ------------
# ['رضا زنجانی', 'رضا زنجانی']
# سید رضا زنجانی
# ------------
# ['آستانهٔ پیروزی انقلاب ۱۳۵۷', '۱۳۵۷']
#
# ------------
# ['آناتولی', 'آناتولی']
# آناتولی یا آسیای کوچک
# ------------
# ['جنوب شرقی', 'جنوب شرقی']
#
# ------------
# ['راهبردی و بسیار خوبی', 'بسیار خوبی']
# دارای موقعیّت جغرافیایی راهبردی و بسیار خوبی است
# ------------
# ['گذرگاه شمال غرب آسیا و اروپا به\u200cشمار می\u200cآید', 'گذرگاه شمال غرب آسیا و اروپا']
#
# ------------
# ['منبع تولید انرژی الکتریکی', 'یک منبع تولید انرژی الکتریکی']
# با چرخاندن ژنراتور، و تبدیل انرژی مکانیکی به انرژی الکتریکی، به عنوان یک منبع تولید انرژی الکتریکی
# ------------
# ['پمپ کردن آب', 'پمپ کردن آب']
# برای پمپ کردن آب
# ------------
# ['فرنس سیز مجارستانی', 'فرنس سیز']
# رنو تحت هدایت فرنس سیز مجارستانی بود که سرعت متوسطی برابر ۱۰۰ کیلومتر در ساعت داشت.
# ------------
# ['مجموعه\u200cای از مقررات و قوانین', 'مجموعه\u200cای از مقررات و قوانین']
# مجموعه‌ای از مقررات و قوانین است که همهٔ شرکت‌کنندگان و خودروها باید از آن پیروی کنند.
# ------------
# ['تک نفره و به اصطلاح «چرخ باز»', 'تک نفره']
# تک نفره و به اصطلاح «چرخ باز» هستند.
# ------------
# ['چسب', 'نوعی چسب']
# نوعی چسب بسیار خوب است و می‌توان با انحلال آن در حلال‌های مناسب، چسب‌های مختلفی تولید کرد.
# ------------
# ['آمریکای میانه', 'آمریکای میانه']
# اولین استفاده از لاستیک توسط فرهنگ‌های بومی آمریکای میانه
# ------------
# ['ورشکستگی', 'جلوگیری از ورشکستگی']
# برای جلوگیری از ورشکستگی شرکت رولز-رویس، دارایی‌های این شرکت از سوی دولت بریتانیا، ملی اعلام شد
# ------------
# ['آلمانی', 'از نژادهای اصیل آلمانی']
# آلمان
# ------------
# ['رنگهای خیلی کم رنگ یا سفید یک دست', 'خیلی کم رنگ یا سفید']
# رنگهای خیلی کم رنگ یا سفید یک دست قابل قبول نمی‌باشد.
# ------------
# ['رفتارهای اشرافی، شهامت و توانایی آموختن رفتارها', 'رفتارهای اشرافی، شهامت']
# رفتارهای اشرافی، شهامت و توانایی آموختن رفتارها و فعالیت‌های اختصاصی
# ------------
# ['صدها نژاد گوناگون', 'صدها']
# سگ‌ها صدها نژاد گوناگون
# ------------
# ['تازی ایرلندی', 'حدود ۷۶ سانتی\u200cمتر در تازی ایرلندی']
# چی‌واوا
# ------------
# ['اهلی گرگ\u200cها و پستاندار', 'پستاندار']
# اهلی گرگ‌ها و پستانداری از خانواده سگ‌سانان
# ------------
# ['چی\u200cواوا', 'نژاد چی\u200cواوا']
#
# ------------
# ['برنامه\u200cنویس رایانه و یکی از مؤسسان وبگاه شبکه اجتماعی آنلاین فیس\u200cبوک', 'یکی از مؤسسان وبگاه شبکه اجتماعی آنلاین فیس\u200cبوک']
# برنامه‌نویس رایانه و یکی از مؤسسان وبگاه شبکه اجتماعی آنلاین فیس‌بوک در آمریکا است
# ------------
# ['به عنوان مدیر اجرایی در فیس\u200cبوک فعالیت می\u200cکند', 'مدیر اجرایی در فیس\u200cبوک']
# مدیر اجرایی در فیس‌بوک فعالیت می‌کند.
# ------------
# ['میلیاردرهای تصادفی نوشتهٔ بن مزریک', 'میلیاردرهای تصادفی']
# کتاب میلیاردرهای تصادفی نوشتهٔ بن مزریک
# ------------
# ['۴۵ قسمت', '۴۵']
# ۴۵ قسمتی
# ------------
# ['یوسف', 'یوسف را']
# پیامبر بعدی را در نسل او قرار داده و یوسف
# ------------
# ['افرادی که دچار فوبیا هستند ترس غیر منطقی دارند، اما به خاطر ترس و اضطرابشان دیگران را سرزنش نمی\u200cکنند', 'افرادی که دچار فوبیا هستند ترس غیر منطقی دارند، اما به خاطر ترس و اضطرابشان دیگران را سرزنش نمی\u200cکنند']
#
# ------------
# ['پژوهش\u200cها نشان می\u200cدهد', 'پژوهش\u200cها نشان می\u200cدهد']
#
# ------------
# ['نجد عربستان', 'نجد عربستان']
# محمد بن عبدالوهاب در قرن هجدهم در نجد عربستان
# ------------
# ['بازگشت به آموزه\u200cهای اصیل در قرآن و حدیث', 'بازگشت به آموزه\u200cهای اصیل در قرآن و حدیث']
# بازگشت به آموزه‌های اصیل در قرآن و حدیث (سنت پیامبر)
# ------------
# ['جنبشی مذهبی است', 'جنبشی مذهبی']
# جنبشی مذهبی است که محمد بن عبدالوهاب در قرن هجدهم در نجد عربستان بنیان گذاشت
# ------------
# ['شیخ محمد حسین کیخا (مطهری)', 'شیخ محمد حسین کیخا']
# شیخ محمد حسین کیخا (مطهری)،
# ------------
# ['به مکتبخانه رفت', 'مکتبخانه']
# حوزه علمیه مشهد از شهرستان زابل در استان سیستان و بلوچستان به شهرستان فریمان در استان خراسان مهاجرت کرد. مرتضی مطهری در کودکی برای فراگیری دروس ابتدایی به مکتبخانه رفت. در سن دوازده سالگی به حوزه علمیه مشهد
# ------------
# ['دوازده سالگی', 'دوازده سالگی']
# در سن دوازده سالگی
# ------------
# ['عبدالکریم حائری یزدی', 'عبدالکریم حائری یزدی']
#
# ------------
# ['متی بن یونس', 'متی بن یونس']
# «متی بن یونس»
# ------------
# ['یحیی بن عدی', 'یحیی بن عدی']
# «یحیی بن عدی
# ------------
# ['به سلمان محمدی شهرت یافت', 'سلمان محمدی']
# سلمان فارسی حکیمی که خرد و دانش‌های ایرانیان و مسیحیان را می‌دانست از مشاوران محمد، از جمله طراح اصلی حفر خندق در جنگ خندق بوده‌است.
# ------------
# ['پیشنهاد داد تا خندقی ژرف پیرامون مدینه حفر گردد', 'خندقی ژرف پیرامون مدینه حفر گردد']
# خندقی ژرف پیرامون مدینه حفر گردد تا از آن پاسبانی شود.
# ------------
# ['شهرستان پاسارگاد در استان فارس', 'استان فارس']
# در شهرستان پاسارگاد در استان فارس
# ------------
# ['مجموعه\u200cای از سازه\u200cهای باستانی برجای\u200cمانده از دوران هخامنشی', 'مجموعه\u200cای از سازه\u200cهای باستانی']
# مجموعه‌ای از سازه‌های باستانی برجای‌مانده از دوران هخامنشی است
# ------------
# ['هخامنشی', 'هخامنشی']
# دوران هخامنشی
# ------------
# ['مجموعه میراث جهانی پاسارگاد', 'شهرستان پاسارگاد در استان فارس']
# پاسارگاد
# ------------
# ['پادشاه خدایان و فرمانروای تمام زیارتگاه\u200cهای واقع در کوه المپ', 'پادشاه خدایان']
# پادشاه خدایان و فرمانروای تمام زیارتگاه‌های واقع در کوه المپ است.
# ------------
# ['درخشان', 'درخشان']
# نام زئوس مربوط است به کلمهٔ یونانی dios به معنی «درخشان».
# ------------
# ['زئوس ایزد آسمان رخشان و نیز توفان به\u200cشمار می\u200cرفت', 'ایزد آسمان رخشان و نیز توفان']
# زئوس ایزد آسمان رخشان و نیز توفان به‌شمار می‌رفت و هم بدین دلیل سلاح او آذرخش بود که آن را به سمت کسی که او را ناخشنود کرده، پرتاب می‌کرده‌است.
# ------------
# ['دروغگویی، پیمان\u200cشکنی و خیانت', 'دروغگویی، پیمان\u200cشکنی و خیانت']
#
# ------------
# ['کویر یا نمک زار منطقه\u200cای است که به دلیل موقعیت جغرافیایی (معمولاً ختم رودخانه\u200cها در آن) و حرارت شدید آفتاب به نمک\u200cزار بدل شده باشد.', 'کویر به زمین\u200cهای رسی پف\u200cکرده، با شوری و نمک بسیار شدید گفته می\u200cشود که گیاهان نمی\u200cتوانند در آن رشد نمایند.']
# منطقه‌ای است که به دلیل موقعیت جغرافیایی (معمولاً ختم رودخانه‌ها در آن) و حرارت شدید آفتاب به نمک‌زار بدل شده باشد
# ------------
# ['دریاچه یا دریا', 'برخی کویرها قبلاً دریاچه یا دریاهایی بوده\u200cاند که در اثر تبخیر آب از آن\u200cها به نمک\u200cزار بدل شده\u200cاند.']
# دریاچه یا دریاهایی
# ------------
# ['در بعضی از کویرها که شوری خاک کمتر است، ممکن است گیاهانی مانند گز که دربرابر املاح نمکی مقاوم است، در آن رشد نماید.', 'ممکن است گیاهانی مانند گز که دربرابر املاح نمکی مقاوم است، در آن رشد نماید.']
# پوشش گیاهی آن بسیار ضعیف
# ------------
# ['بیابان یا صحرا (به عربی: صحراء) یک زمین\u200cچهر است که به\u200c نوعی از منطقه خشک و کم\u200cباران در جغرافیای کره زمین گفته می\u200cشود و به خاطر بارندگی سالیانهٔ کم دارای پوشش گیاهی کمی است.', 'یک زمین\u200cچهر است که به\u200c نوعی از منطقه خشک و کم\u200cباران در جغرافیای کره زمین گفته می\u200cشود و به خاطر بارندگی سالیانهٔ کم دارای پوشش گیاهی کمی است.']
# یک زمین‌چهر است که به‌ نوعی از منطقه خشک و کم‌باران در جغرافیای کره زمین گفته می‌شود
# ------------
# ['در فارسی به بیابان بسیار خشک و خالی بیابان برهوت گفته می\u200cشود.', 'بیابان بسیار خشک و خالی']
# در فارسی به بیابان بسیار خشک و خالی بیابان
# ------------
# ['یکی از زبان\u200cهای سامی و یکی از شش زبان\u200cهای رسمی سازمان ملل متحد، زبان مقدس در اسلام، زبان رسمی در جهان عرب، و زبان اقلیت در بقیه کشورهای شمال آفریقا است.', 'یکی از شش زبان\u200cهای رسمی سازمان ملل متحد، زبان مقدس در اسلام، زبان رسمی در جهان عرب']
# در دوران طلایی اسلام، عربی به عنوان نخستین زبان جهان اسلام از اهمیت بالایی برخوردار بود
# ------------
# ['این زبان را «لغة الضاد» نیز می\u200cنامند', 'العَرَبِيّة']
# اللُّغَة العَرَبِيّة
# ------------
# ['زیرا تنها زبانی است که دارای ضاد می\u200cباشد و ضاد حرفی\u200cست که سخت\u200cترین شیوهٔ کاربرد را دارد، زبان آلبانیایی هم پس از ورود زبان عربی، حرف ضاد وارد آن شد.', 'زیرا تنها زبانی است که دارای ضاد می\u200cباشد و ضاد حرفی\u200cست که سخت\u200cترین شیوهٔ کاربرد را دارد']
# زیرا تنها زبانی است که دارای ضاد می‌باشد
# ------------
# ['امروزه این زبان دارای۱۳ لهجه\u200c و گویش\u200cهای گوناگون است ولی عربی نوین معیار به عنوان زبان رسمی نوشتار در همهٔ کشورهای عربی پذیرفته شده\u200cاست.', 'عربی نوین معیار به عنوان زبان رسمی نوشتار در همهٔ کشورهای عربی پذیرفته شده\u200cاست.']
# زبان رسمی نوشتار
# ------------
# ['در شهر کریات آتا در شمال اسرائیل', 'شهر کریات']
# شهر کریات آتا در شمال اسرائیل
# ------------
# ['غلوله', '«غلوله» و «گولوله»']
# نوک تیز یا اسپیتزر
# ------------
# ['از فلز (بیشتر سرب) ساخته می\u200cشود و معمولاً فاقد مواد منفجره است.', 'از فلز (بیشتر سرب) ساخته می\u200cشود']
# گلوله معمولاً از فلز (بیشتر سرب)
# ------------
# ['کالیبر با فونت بخصوص، آلیاژ پوسته گلوله و سه دندانه در جایی که چاشنی به پوکه فشنگ وصل می\u200cشود', 'در جایی که چاشنی به پوکه فشنگ وصل می\u200cشود، نشان\u200cدهنده یک سازنده مشترک است.']
# مُهر کالیبر با فونت بخصوص، آلیاژ پوسته گلوله و سه دندانه در جایی که چاشنی به پوکه فشنگ وصل می‌شود
# ------------
# ['دارای علامت\u200cگذاری کالیبر ساده هستند که معمولاً دو رقم آخر سال ساخت گلوله را نشان می\u200cدهند.', 'دارای مُهرهایی هستند که در بایگانی\u200cهای عمومی اطلاعات مربوط به سازندگان سلاح موجود است.']
# علامت‌گذاری کالیبر ساده هستند که معمولاً دو رقم آخر سال ساخت گلوله را نشان می‌دهند
# ------------
# ['از قرن نوزدهم شکل گلوله\u200cها تغییر کرد و به صورت کشیده و نوک تیز یا اسپیتزر درآمد.', 'به صورت کشیده و نوک تیز یا اسپیتزر درآمد.']
# به صورت کشیده و نوک تیز یا اسپیتزر
# ------------
# ['از باشگاه المپیک لیون', 'المپیک لیون']
# باشگاه المپیک لیون
# ------------
# ['بهترین گلزن فرانسوی', 'بهترین گلزن فرانسوی']
# بهترین گلزن فرانسوی تاریخ لیگ قهرمانان اروپا
# ------------
# ['به معنی دوستی و پذیرش سرپرستی خدا، پیامبران، امام و دعات(مبلغین) است', 'دوستی و پذیرش سرپرستی خدا، پیامبران، امام و دعات']
# دوستی و پذیرش سرپرستی خدا، پیامبران، امام و دعات(مبلغین) است.
# ------------
# ['برای تقیه جایز می\u200cدانند', 'جایز می\u200cدانند']
# شرکت در نماز جماعت را برای تقیه جایز می‌دانند
# ------------
# ['طهارت را از ارکان دین نمی\u200cدانند', 'طهارت را از ارکان دین نمی\u200cدانند']
# درزیان طهارت را از ارکان دین نمی‌دانند
# ------------
# ['وی استاد ملی\u200cگرای رشتهٔ حقوق در دانشگاه تهران و وکیل دعاوی در تهران بود', 'استاد ملی\u200cگرای رشتهٔ حقوق در دانشگاه تهران و وکیل دعاوی در تهران بود']
# تاریخ‌نگار، زبان‌شناس، پژوهشگر، حقوق‌دان و اندیشمند
# ------------
# ['پاک\u200cدینی', 'پاک\u200cدینی']
# جنبش «پاک‌دینی»
# ------------
# ['شعرهای خیام، حافظ، سعدی و دیگران شاعران ایرانی', 'خیام، حافظ، سعدی و دیگران شاعران ایرانی']
# خیام، حافظ، سعدی
# ------------
# ['آموزه و روشی سیاسی است', 'آموزه و روشی سیاسی']
# آموزه و روشی سیاسی است در طرفداری کردن یا طرفداری نشان دادن از حقوق و علایق مردم عامه در برابر گروه نخبه.
# ------------
# ['با جنبش\u200cهای آمریکای لاتین و هند', 'با جنبش\u200cهای آمریکای لاتین و هند']
# جنبش‌های آمریکای لاتین و هند
# ------------
# ['مساحت خلیج فارس ۲۳۷٬۴۷۳ کیلومتر مربع است، طول آن حدود ۹۰۰ کیلومتر و عرض متوسط آن ۲۵۰ کیلومتر است', 'مساحت خلیج فارس ۲۳۷٬۴۷۳ کیلومتر مربع است']
# طول آن حدود ۹۰۰ کیلومتر و عرض متوسط آن ۲۵۰ کیلومتر
# ------------
# ['خلیج فارس از شرق از طریق تنگه هرمز و دریای عمان به اقیانوس هند و دریای عرب راه دارد', 'دریای عمان']
#
# ------------
# ['قالی، فرش یا قالین نوعی گستردنیِ بافته شده از الیاف پنبه، پشم و در بعضی موارد ابریشم است که معمولاً برای پوشش زمین به کار می\u200cرود.', 'به دست بافتهٔ پُرزدار و گره\u200cدار، قالی گفته می\u200cشود.']
# نوعی گستردنیِ بافته شده از الیاف پنبه، پشم و در بعضی موارد ابریشم است
# ------------
# ['از نام شهری به نام قالین در ارمنستان که در آن دوران بخشی از ایران باستان بوده\u200cاست، گرفته شده\u200cاست.', 'از نام شهری به نام قالین']
# از نام شهری به نام قالین در ارمنستان که در آن دوران بخشی از ایران باستان بوده‌است
# ------------
# ['از کلمهٔ ترکی قالین به معنای فرشِ پُرزدار که با نخ و پشم به رنگ\u200cهای مختلف بافته می\u200cشود', 'از کلمهٔ ترکی قالین']
# کلمهٔ ترکی قالین
# ------------
# ['تحت پشتیبانی شاهان قدرتمندی چون شاه عباس قرارگرفتن بود و دسترسی فراوان به مواد مورد نیاز برای بافت فرش و همچنین به\u200cرسمیت\u200cشناختنِ فرش به عنوان کالایی برای تجارت بوده\u200cاست', 'تحت پشتیبانی شاهان قدرتمندی چون شاه عباس قرارگرفتن بود']
# تحت پشتیبانی شاهان قدرتمندی چون شاه عباس قرارگرفتن بود و دسترسی فراوان به مواد مورد نیاز برای بافت فرش و همچنین به‌رسمیت‌شناختنِ فرش به عنوان کالایی برای تجارت
# ------------
# ['از آنجا که قالی و فرش همیشه نقش\u200cهای زیبا بر خود داشته\u200cاند، امروزه به جنبهٔ تزئینی آن نیز توجه می\u200cشود.', 'قالی و فرش همیشه نقش\u200cهای زیبا بر خود داشته\u200cاند']
# از آنجا که قالی و فرش همیشه نقش‌های زیبا بر خود داشته‌اند
# ------------
# ['قدیمی\u200cترین قالیِ دستبافِ یافته\u200cشدهٔ جهان است که در سیبری کشف شده و بافت ایران در دوران هخامنشیان است.', 'قدیمی\u200cترین قالیِ دستبافِ یافته\u200cشدهٔ جهان است']
# قدیمی‌ترین قالیِ دستبافِ یافته‌شدهٔ جهان
# ------------
# ['به شکل یک زن زیبا', 'زن زیبا']
#
# ------------
# ['دمی', 'دم']
# سر و تنه
# ------------
# ['افسانه\u200cهای سیرن', 'افسانه\u200cهای سیرن']
# افسانه‌های سیرن (حوری دریایی اسطوره‌های یونان)
# ------------
# ['مزه\u200cها، یک احساس است که توسط حس چشایی آشکار می\u200cشود.', 'مزه یک احساس کلی می\u200cباشد؛']
# یک احساس است که توسط حس چشایی آشکار می‌شود.
# ------------
# ['هرآن چه را که حس چشایی احساس کند مزه دارد و هرآن چه را که احساس نکند مزه ندارد.', 'هرآن چه را که حس چشایی احساس کند']
#
# ------------
# ['مزه\u200cای به نام تندی در دهان وجود ندارد. این احساس مربوط به ماده ای است به نام کاپسی سین که در فلفل\u200cهای تند وجود دارد.', 'تندی یک مزه نیست چون مربوط به حس لامسه می\u200cشود.']
# این احساس مربوط به ماده ای است به نام کاپسی سین که در فلفل‌های تند وجود دارد.
# ------------
# ['شیرینی (مزه)، تلخی (مزه)، ترشی (مزه)، شوری (مزه)، ملسی', 'مزه\u200cای به نام تندی در دهان وجود ندارد.']
#
# ------------
# ['در بعضی از دسته\u200cبندی\u200cها مزه اومامی را به عنوان مزه پنجم ذکر می\u200cکنند، اومامی کلمه ای ژاپنی به معنای لذیذ است', 'اومامی کلمه ای ژاپنی به معنای لذیذ است که برای توصیف یک مزه مطلوب که با چهار مزه دیگر تفاوت دارد، بکار می\u200cرود.']
# اومامی مزه غالب غذاهایی است که آمینو اسید گلوتامات دارند، مانند عصاره گوشت و گوجه فرنگی.
# ------------
# ['طعم غذا ترکیبی از حس چشایی و بوی غذاست.', 'تعریف دیگر طعم این است: مزه +بو']
# مزه‌ها، یک احساس است که توسط حس چشایی آشکار می‌شود
# ------------
# ['اومامی مزه غالب غذاهایی است که آمینو اسید گلوتامات دارند', 'مانند عصاره گوشت و گوجه فرنگی.']
# اومامی مزه غالب غذاهایی است که آمینو اسید گلوتامات دارند، مانند عصاره گوشت و گوجه فرنگی.
# ------------
# ['دستگاه حسی-پیکری مجموعه پیچیده ای از نورون های حسی و مسیرهای عصبی است که به تغییرات در سطح یا داخل بدن واکنش می دهند.', 'بخشی از دستگاه حسی است.']
# مجموعه پیچیده ای از نورون های حسی و مسیرهای عصبی است که به تغییرات در سطح یا داخل بدن واکنش می دهند.
# ------------
# ['این سلول\u200cهای گیرنده حسی توسط تحریکات مختلفی چون گرما و درد فعال شده و به همین دلیل نام این نورون ها مربوط به نوع واکنشی است که از خود بروز می دهند.', 'این سلول\u200cهای گیرنده حسی توسط تحریکات مختلفی چون گرما و درد فعال شده']
#
# ------------
# ['هومونکولوس قشری (یا انسان مینیاتوری قشری) می گویند.', 'انسان مینیاتوری قشری']
# هومونکولوس قشری (یا انسان مینیاتوری قشری)
# ------------
# ['۸۰٪ مردم دانمارک مسیحی پروتستان هستند', 'مسیحی پروتستان']
# ۸۰٪ مردم دانمارک مسیحی پروتستان
# ------------
# ['تنها مرزی که دارد با کشور آلمان است', 'آلمان']
#
# ------------
# ['شش\u200cضلعی', 'شش\u200cضلعی']
# جمهوری فرانسه
# ------------
# ['از جنوب با موناکو مرز زمینی دارد', 'موناکو']
# آندورا و اسپانیا
# ------------
# ['دومین کشور پرجمعیت', 'دومین کشور']
# دومین کشور پرجمعیت پس از آلمان در اتحادیه اروپا قرار می‌گیرد.
# ------------
# ['دومین کشور پرجمعیت دنیا', 'دومین کشور']
# دومین کشور پرجمعیت دنیا پس از چین به‌شمار می‌آید.
# ------------
# ['بسیار طولانی و درخشان', 'بسیار طولانی و درخشان']
# یونان دارای تاریخی بسیار طولانی و درخشان در عرصه جهانی است.
# ------------
# ['در انتهای جنوبی شبه جزیره عربستان در آسیای غربی است', 'انتهای جنوبی شبه جزیره عربستان در آسیای غربی']
# در انتهای جنوبی شبه جزیره عربستان در آسیای غربی
# ------------
# ['بین امپراتوریهای عثمانی و انگلیس تقسیم شد', 'بین امپراتوریهای عثمانی و انگلیس تقسیم شد']
# این کشور در سالهای ۱۸۰۰ بین امپراتوریهای عثمانی و انگلیس تقسیم شد.
# ------------
# ['به دسته\u200cای از مواد مصنوعی یا نیمه مصنوعی گویند که از فرایند بسپارش بدست می\u200cآیند.', 'پ']
# پلاستیک به دسته‌ای از مواد مصنوعی یا نیمه مصنوعی گویند که از فرایند بسپارش بدست می‌آیند.
# ------------
# ['اصولاً یکی از ویژگی\u200cهای پلاستیک\u200cها شکل\u200cپذیری خوب آن\u200cهاست.', 'پلاستیک\u200cها را می\u200cتوان تحت فرایندهای گرمایی و مکانیکی به شکل\u200cهای دیگر درآورد.']
# شکل‌پذیری خوب آن‌هاست.
# ------------
# ['بر اساس طبیعت محصول، پلاستیک\u200cها ممکن است با فرایند متوالی یا غیر متوالی تولید شوند.', 'با فرایند متوالی یا غیر متوالی']
# با فرایند متوالی یا غیر متوالی تولید شوند.
# ------------
# ['مواد مصنوعی است و به\u200cصورت طبیعی یافت نمی\u200cشود.', 'از مواد مصنوعی']
# مواد مصنوعی
# ------------
# ['از الیافی نرم و پف\u200cدار است که درون کپسولی به دور تخم\u200cهای گیاه پنبه می\u200cروید.', 'از الیافی نرم و پف\u200cدار است']
# از الیاف پوشانندهٔ دانهٔ گیاه پنبه
# ------------
# ['اختراع پنبه\u200cریسی بود که هزینه تولید پارچه از این راه را پایین آورد و باعث بهره\u200cگیری گسترده از پنبه شد به گونه\u200cای که امروزه پرکاربردترین الیاف به کار رفته در صنعت پوشاک است.', 'اختراع پنبه\u200cریسی بود که هزینه تولید پارچه از این راه را پایین آورد']
#
# ------------
# ['پنبه در تورهای ماهی\u200cگیری، فیلتر قهوه و چای، مواد منفجره (نیتروسلولز)، کاغذ و صحافی … استفاده می\u200cشود.', 'در تورهای ماهی\u200cگیری، فیلتر قهوه و چای، مواد منفجره (نیتروسلولز)']
# پنبه در تورهای ماهی‌گیری، فیلتر قهوه و چای، مواد منفجره (نیتروسلولز)، کاغذ و صحافی
# ------------
# ['۶۲۲ میلادی', 'سال ۶۲۲ میلادی']
# در سال ۶۲۲ میلادی
# ------------
# ['تاتلیسس افزون\u200cبر زبان ترکی، به زبان\u200cهای عربی و کردی نیز تسلط کامل دارد', 'تاتلیسس افزون\u200cبر زبان ترکی، به زبان\u200cهای عربی و کردی نیز تسلط کامل دارد']
# تاتلیسس افزون‌بر زبان ترکی، به زبان‌های عربی و کردی
# ------------
# ['جنوب ترکیه و در شهر شانلی\u200cاورفه', 'شهر شانلی\u200cاورفه']
# وی در جنوب ترکیه و در شهر شانلی‌اورفه
# ------------
# ['کشورهای خاورمیانه مثل جمهوری آذربایجان، ایران، افغانستان، عراق و سوریه', 'کشورهای خاورمیانه']
# آسیای میانه و کشورهای خاورمیانه مثل جمهوری آذربایجان، ایران، افغانستان، عراق و سوریه
# ------------
# ['شیره درخت افرا که از آن شکر تولید می\u200cشود و نیز شیره درختان کائوچوکی که در صنعت لاستیک\u200cسازی کاربرد دارند.', 'شیره درخت افرا که از آن شکر تولید می\u200cشود و نیز شیره درختان کائوچوکی']
# درخت افرا که از آن شکر تولید می‌شود و نیز شیره درختان کائوچوکی
# ------------
# ['تریاک نیز در واقع شیره گرز خشخاش است که با خراش دادن از گیاه خارج شده و در مجاورت هوا سفت می\u200cشود.', 'تریاک نیز در واقع شیره گرز خشخاش است که با خراش دادن از گیاه خارج شده']
# با خراش دادن از گیاه خارج شده و در مجاورت هوا سفت می‌شود.
# ------------
# ['ابتدا آب انگور را از انگور جدا می\u200cکنند سپس نوعی خاک قلیایی به آن اضافه می\u200cکنند که باعث می\u200cشود تفاله انگور به همراه خاک ته\u200cنشین شود', 'نوعی خاک قلیایی به آن اضافه می\u200cکنند که باعث می\u200cشود تفاله انگور به همراه خاک ته\u200cنشین شود']
# ابتدا آب انگور را از انگور جدا می‌کنند سپس نوعی خاک قلیایی به آن اضافه می‌کنند
# ------------
# ['معمولاً از انگور کشمشی سفید که مزه\u200cای شیرین دارد بدست می\u200cآورند.', 'از انگور کشمشی سفید']
# انگور کشمشی سفید
# ------------
# ['گیاهی بزرگ، پهن و یک ساله و یک پایه است. ساقهٔ خزنده و برگ\u200cهای پهن و کرک\u200cدار با بریدگی\u200cهای ژرف و گل\u200cهای سفید یا زرد دارد.', 'گیاهی بزرگ، پهن و یک ساله و یک پایه است.']
# گیاهی بزرگ، پهن و یک ساله و یک پایه است. ساقهٔ خزنده و برگ‌های پهن و کرک‌دار با بریدگی‌های ژرف و گل‌های سفید یا زرد دارد. هندوانه گیاهی گرمسیری یا نیمه گرمسیری
# ------------
# ['توسط دانشمندان ژاپنی که قادر به تولید دورگه تری پلوئیدی بی\u200cدانه بودند پرورش داده شد؛', 'هندوانه\u200cهای بی\u200cدانه اولین بار در سال ۱۹۳۹ توسط دانشمندان ژاپنی']
#
# ------------
# ['هندوانه گیاهی گرمسیری یا نیمه گرمسیری است و برای رشد به دمایی بالاتر از حدود ۲۵ درجه سانتیگراد نیاز دارد.', 'هندوانه گیاهی گرمسیری یا نیمه گرمسیری است']
# جالیز
# ------------

# %%
print(f"Exact Match Score: {em_score}")
print(f"Average F1 Score: {average_f1_score}")
print(f"Inclusion Rate: {include}")
# Out:
# Exact Match Score: 0.6251920122887865
# Average F1 Score: 0.8119925803593003
# Inclusion Rate: 0.858678955453149

# %%
predictions[5]
# Out:
# 'کلمهٔ رئال در زبان اسپانیایی، به معنی «سلطنتی» است، این لقب را شاه آلفونسو سیزدهم در سال ۱۹۲۰ بر این تیم نهاد.'

# %%
answers[5]
# Out:
# ['شاه آلفونسو سیزدهم در سال ۱۹۲۰ بر این تیم نهاد', 'شاه آلفونسو سیزدهم']

# %%
questions[5]
# Out:
# 'لقب باشگاه رئال مادرید از کجا میاد؟'
